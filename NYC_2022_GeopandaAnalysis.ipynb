# %% [markdown]
# <a href="https://colab.research.google.com/github/nirumano/NYC_GIS_DataAnalysis/blob/main/NYC_2022_GeopandaAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Importing Libraries**

# %%
import pandas as pd
import geopandas as gpd

from getpass import getpass
import plotly.express as px

import requests
import warnings

pd.set_option('display.max_columns', None)
warnings.filterwarnings("ignore")

census_api_key = getpass('Enter the api key: ')
# Out:
# Enter the api key: ··········

# %% [markdown]
# # **Census API Request Setup**

# %%
censusCode = 'B19013_001E' # Median household income code
year = '2022'
state = '36' # NYC
county_code = '061' #Manhattan
census_url = f'https://api.census.gov/data/{year}/acs/acs5?get=NAME,{census_code}&for=tract:*&in=state:{state}&in=county:{county_code}&key={census_api_key}'
response = requests.get(census_url)

# %%
df = gpd.read_file(f"https://www2.census.gov/geo/tiger/TIGER{year}/TRACT/tl_{year}_{state}_tract.zip")
df.head()
# Out:
#   STATEFP COUNTYFP TRACTCE        GEOID    NAME             NAMELSAD  MTFCC  \
# 0      36      007  012702  36007012702  127.02  Census Tract 127.02  G5020
# 1      36      007  012800  36007012800     128     Census Tract 128  G5020
# 2      36      007  012900  36007012900     129     Census Tract 129  G5020
# 3      36      007  013000  36007013000     130     Census Tract 130  G5020
# 4      36      007  013202  36007013202  132.02  Census Tract 132.02  G5020
#
#   FUNCSTAT     ALAND  AWATER     INTPTLAT      INTPTLON  \
# 0        S  65461841  222705  +42.0350532  -075.9055509
# 1        S  12342848  259435  +42.1298743  -075.9096569
# 2        S  14480163   63649  +42.1522758  -075.9766029
# 3        S   9934434  381729  +42.1236499  -076.0002197
# 4        S   2446208    3681  +42.1238924  -076.0311921
#
#                                             geometry
# 0  POLYGON ((-75.95917 42.00852, -75.95914 42.008...
# 1  POLYGON ((-75.94766 42.13727, -75.94453 42.137...
# 2  POLYGON ((-76.02229 42.15699, -76.01917 42.157...
# 3  POLYGON ((-76.02417 42.12590, -76.02409 42.125...
# 4  POLYGON ((-76.03996 42.13285, -76.03862 42.132...

# %%
df.shape
# Out:
# (5411, 13)

# %%
censusDF = pd.DataFrame(response.json())
censusDF.head()
# Out:
#                                               0            1      2       3  \
# 0                                          NAME  B19013_001E  state  county
# 1     Census Tract 1; New York County; New York   -666666666     36     061
# 2  Census Tract 2.01; New York County; New York        45582     36     061
# 3  Census Tract 2.02; New York County; New York        34710     36     061
# 4     Census Tract 5; New York County; New York   -666666666     36     061
#
#         4
# 0   tract
# 1  000100
# 2  000201
# 3  000202
# 4  000500

# %% [markdown]
# # **Organize Dataset: Column/Row cleaning & GEOID Creation**

# %%
censusDF.columns = censusDF.iloc[0]
censusDF = censusDF.drop(censusDF.index[0])
censusDF.head()
# Out:
# 0                                          NAME B19013_001E state county  \
# 1     Census Tract 1; New York County; New York  -666666666    36    061
# 2  Census Tract 2.01; New York County; New York       45582    36    061
# 3  Census Tract 2.02; New York County; New York       34710    36    061
# 4     Census Tract 5; New York County; New York  -666666666    36    061
# 5     Census Tract 6; New York County; New York       25655    36    061
#
# 0   tract
# 1  000100
# 2  000201
# 3  000202
# 4  000500
# 5  000600

# %%
censusDF['GEOID'] = censusDF['state'] + censusDF['county'] + censusDF['tract']
censusDF[censusCode] = censusDF[censusCode].astype(int)
censusDF.head()
# Out:
# 0                                          NAME  B19013_001E state county  \
# 1     Census Tract 1; New York County; New York   -666666666    36    061
# 2  Census Tract 2.01; New York County; New York        45582    36    061
# 3  Census Tract 2.02; New York County; New York        34710    36    061
# 4     Census Tract 5; New York County; New York   -666666666    36    061
# 5     Census Tract 6; New York County; New York        25655    36    061
#
# 0   tract        GEOID
# 1  000100  36061000100
# 2  000201  36061000201
# 3  000202  36061000202
# 4  000500  36061000500
# 5  000600  36061000600

# %% [markdown]
# # **Check for Outlier Data**

# %%
censusDF[censusCode].describe().apply("{0:.5f}".format)
# Out:
# count           310.00000
# mean      -23544020.96774
# std       123553829.57769
# min      -666666666.00000
# 25%           57902.25000
# 50%          107666.50000
# 75%          159835.00000
# max          250001.00000
# Name: B19013_001E, dtype: object

# %%
filterCensusDF = censusDF.loc[censusDF[censusCode] > 0]
filterCensusDF.head()
# Out:
# 0                                          NAME  B19013_001E state county  \
# 2  Census Tract 2.01; New York County; New York        45582    36    061
# 3  Census Tract 2.02; New York County; New York        34710    36    061
# 5     Census Tract 6; New York County; New York        25655    36    061
# 6     Census Tract 7; New York County; New York       184730    36    061
# 7     Census Tract 8; New York County; New York        28607    36    061
#
# 0   tract        GEOID
# 2  000201  36061000201
# 3  000202  36061000202
# 5  000600  36061000600
# 6  000700  36061000700
# 7  000800  36061000800

# %%
filterCensusDF.shape
# Out:
# (299, 6)

# %%
filterCensusDF[censusCode].describe()
# Out:
# count       299.000000
# mean     116009.451505
# std       62480.743786
# min       11406.000000
# 25%       63300.500000
# 50%      112969.000000
# 75%      160780.000000
# max      250001.000000
# Name: B19013_001E, dtype: float64

# %% [markdown]
# # **Merge through Inner Join with Filtered Data & source DataFrame**

# %%
dfMerged = pd.merge(filterCensusDF, df,on=['GEOID'], how='inner')
dfGEO = gpd.GeoDataFrame(dfMerged).set_index('GEOID')
dfGEO.head()
# Out:
#                                                    NAME_x  B19013_001E state  \
# GEOID
# 36061000201  Census Tract 2.01; New York County; New York        45582    36
# 36061000202  Census Tract 2.02; New York County; New York        34710    36
# 36061000600     Census Tract 6; New York County; New York        25655    36
# 36061000700     Census Tract 7; New York County; New York       184730    36
# 36061000800     Census Tract 8; New York County; New York        28607    36
#
#             county   tract STATEFP COUNTYFP TRACTCE NAME_y           NAMELSAD  \
# GEOID
# 36061000201    061  000201      36      061  000201   2.01  Census Tract 2.01
# 36061000202    061  000202      36      061  000202   2.02  Census Tract 2.02
# 36061000600    061  000600      36      061  000600      6     Census Tract 6
# 36061000700    061  000700      36      061  000700      7     Census Tract 7
# 36061000800    061  000800      36      061  000800      8     Census Tract 8
#
#              MTFCC FUNCSTAT   ALAND  AWATER     INTPTLAT      INTPTLON  \
# GEOID
# 36061000201  G5020        S   90233   75976  +40.7098961  -073.9855833
# 36061000202  G5020        S  310040  428737  +40.7056637  -073.9814548
# 36061000600  G5020        S  240406  176018  +40.7102579  -073.9880558
# 36061000700  G5020        S  253229  246239  +40.6995508  -073.9987690
# 36061000800  G5020        S  220708  167906  +40.7101181  -073.9932525
#
#                                                       geometry
# GEOID
# 36061000201  POLYGON ((-73.98717 40.71431, -73.98608 40.714...
# 36061000202  POLYGON ((-73.98534 40.71446, -73.98471 40.714...
# 36061000600  POLYGON ((-73.99256 40.71439, -73.99213 40.714...
# 36061000700  POLYGON ((-74.01251 40.70677, -74.01195 40.707...
# 36061000800  POLYGON ((-73.99744 40.71407, -73.99648 40.714...

# %% [markdown]
# # **Visualize Data**

# %%
df_geo_county = dfGEO.loc[dfGEO['county'] == '061']
fig = px.choropleth_mapbox(df_geo_county,
                        geojson=df_geo_county.geometry,
                        locations=df_geo_county.index,
                        color=censusCode,
                        color_continuous_scale='Viridis',
                        opacity=0.5,
                        center={"lat": 40.7831 , "lon": -73.9712},
                        mapbox_style="open-street-map",
                        zoom=10.0,
                        title='Manhattan, NYC: Median Household Income 2022'
                        )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="73c9a973-0aa6-41e6-b31c-ccb5ca04e4a8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("